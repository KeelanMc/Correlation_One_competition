# %%
x=[[1,2],[2,4]]

# %%
list(range(22,27))
# Out:
# [22, 23, 24, 25, 26]

# %%
y = [[2,3],[5,6]]

# %%
for i in x:
    print (i)
# Out:
# [1, 2]
# [2, 4]

# %%
[i for i in x if i[1]<=2]
# Out:
# [[1, 2]]

# %%
x, y = map(int, [1,2])

# %%
print(list(range(2)).append(list(range(25,28))))
# Out:
# None

# %%
[ i for i in [list(range(2)).append(range(25,28))]
# Out:
#   File "<ipython-input-9-1c5dbac2f58c>", line 1
#     [ i for i in [list(range(2)).append(range(25,28))]
#                                                       ^
# SyntaxError: unexpected EOF while parsing

# %%
[[i,j] for i in range(14) for j in range(13-i,13+i+2)]
# Out:
# [[0, 13],
#  [0, 14],
#  [1, 12],
#  [1, 13],
#  [1, 14],
#  [1, 15],
#  [2, 11],
#  [2, 12],
#  [2, 13],
#  [2, 14],
#  [2, 15],
#  [2, 16],
#  [3, 10],
#  [3, 11],
#  [3, 12],
#  [3, 13],
#  [3, 14],
#  [3, 15],
#  [3, 16],
#  [3, 17],
#  [4, 9],
#  [4, 10],
#  [4, 11],
#  [4, 12],
#  [4, 13],
#  [4, 14],
#  [4, 15],
#  [4, 16],
#  [4, 17],
#  [4, 18],
#  [5, 8],
#  [5, 9],
#  [5, 10],
#  [5, 11],
#  [5, 12],
#  [5, 13],
#  [5, 14],
#  [5, 15],
#  [5, 16],
#  [5, 17],
#  [5, 18],
#  [5, 19],
#  [6, 7],
#  [6, 8],
#  [6, 9],
#  [6, 10],
#  [6, 11],
#  [6, 12],
#  [6, 13],
#  [6, 14],
#  [6, 15],
#  [6, 16],
#  [6, 17],
#  [6, 18],
#  [6, 19],
#  [6, 20],
#  [7, 6],
#  [7, 7],
#  [7, 8],
#  [7, 9],
#  [7, 10],
#  [7, 11],
#  [7, 12],
#  [7, 13],
#  [7, 14],
#  [7, 15],
#  [7, 16],
#  [7, 17],
#  [7, 18],
#  [7, 19],
#  [7, 20],
#  [7, 21],
#  [8, 5],
#  [8, 6],
#  [8, 7],
#  [8, 8],
#  [8, 9],
#  [8, 10],
#  [8, 11],
#  [8, 12],
#  [8, 13],
#  [8, 14],
#  [8, 15],
#  [8, 16],
# ...

# %%
top_right = []
for num in range(0, 14):
    x = 14 + num
    y = 14 - 1 - num
    top_right.append([int(x), int(y)])

# %%
bottom_left =[]
for num in range(0, 14):
    x = 14 - 1 - num
    y = num
    bottom_left.append([int(x), int(y)])
bottom_right = []
for num in range(0, 14):
    x = 14 + num
    y = num
    bottom_right.append([int(x), int(y)])
x_cors = [list(range(bottom_left[i][0],bottom_right[i][0]+1)) for i in range(len(bottom_left))]
allfriendlypos = [[xcorrsamp[i],(len(xcorrsamp)-2)/2]  for xcorrsamp in x_cors for i in range(len(xcorrsamp))]

# %%
x_cors = [list(range(bottom_left[i][0],bottom_right[i][0]+1)) for i in range(len(bottom_left))]

# %%
[[xcorrsamp[i],(len(xcorrsamp)-2)/2]  for xcorrsamp in x_cors for i in range(len(xcorrsamp))]
# Out:
# [[13, 0.0],
#  [14, 0.0],
#  [12, 1.0],
#  [13, 1.0],
#  [14, 1.0],
#  [15, 1.0],
#  [11, 2.0],
#  [12, 2.0],
#  [13, 2.0],
#  [14, 2.0],
#  [15, 2.0],
#  [16, 2.0],
#  [10, 3.0],
#  [11, 3.0],
#  [12, 3.0],
#  [13, 3.0],
#  [14, 3.0],
#  [15, 3.0],
#  [16, 3.0],
#  [17, 3.0],
#  [9, 4.0],
#  [10, 4.0],
#  [11, 4.0],
#  [12, 4.0],
#  [13, 4.0],
#  [14, 4.0],
#  [15, 4.0],
#  [16, 4.0],
#  [17, 4.0],
#  [18, 4.0],
#  [8, 5.0],
#  [9, 5.0],
#  [10, 5.0],
#  [11, 5.0],
#  [12, 5.0],
#  [13, 5.0],
#  [14, 5.0],
#  [15, 5.0],
#  [16, 5.0],
#  [17, 5.0],
#  [18, 5.0],
#  [19, 5.0],
#  [7, 6.0],
#  [8, 6.0],
#  [9, 6.0],
#  [10, 6.0],
#  [11, 6.0],
#  [12, 6.0],
#  [13, 6.0],
#  [14, 6.0],
#  [15, 6.0],
#  [16, 6.0],
#  [17, 6.0],
#  [18, 6.0],
#  [19, 6.0],
#  [20, 6.0],
#  [6, 7.0],
#  [7, 7.0],
#  [8, 7.0],
#  [9, 7.0],
#  [10, 7.0],
#  [11, 7.0],
#  [12, 7.0],
#  [13, 7.0],
#  [14, 7.0],
#  [15, 7.0],
#  [16, 7.0],
#  [17, 7.0],
#  [18, 7.0],
#  [19, 7.0],
#  [20, 7.0],
#  [21, 7.0],
# ...
